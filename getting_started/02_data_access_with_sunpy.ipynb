# %% [markdown]
# # HPA Data Access with `sunpy`
#
# ```
# Author: ESDC Team at ESAC
# Date Last Modified: 20/08/2026
# ```
#
# This notebook demonstrate programmatic access to the data in ESA's [HPA](https://hpa.esa.int) using the Table Access Protocol (TAP) and the Astronomical Query Language (ADQL) with the [sunpy](https://sunpy.org/) `python` package.
#
# Accessing the HPA via `astroquery` has the following *advantages* (+) and *disadvantages* (-) compared to `astroquery` and `PyVO`:
#
# Refer to the other tutorials in the [Getting Started](https://github.com/HPA-ESDC-ESA-INT/HPA-Jupyter-Notebooks/tree/main/getting_started) section for more information on `astroquery` and `PyVO`.
