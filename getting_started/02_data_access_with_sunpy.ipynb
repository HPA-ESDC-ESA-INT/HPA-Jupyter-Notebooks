# %% [markdown]
# # HPA Data Access with `sunpy`
#
# ```
# Author: ESDC Team at ESAC
# Date Last Modified: 20/08/2026
# ```
#
# This notebook demonstrate programmatic access to the data in ESA's [HPA](https://hpa.esa.int) using the [sunpy](https://sunpy.org/) `python` package.
#
# TBD.
